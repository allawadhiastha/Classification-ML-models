# %% [markdown]
# # Classification Day - 3

# %% [markdown]
# #Pixel Data Set - Kaggle

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ptrain=pd.read_csv("train_pix.csv")
ptest=pd.read_csv("test_pix.csv")

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lm=LogisticRegression()

# %%
x=ptrain.drop("label",axis = 1)
y=ptrain.label

# %%
model_lg=lm.fit(x,y).predict(ptest)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
solution_pix = pd.DataFrame({"Label":model_lg})

# %%
solution_pix.to_csv("Solution_pix.csv", index = False)

# %%
cd
# Out:
# C:\Users\Astha

# %% [markdown]
# # Wine Quality

# %%
wine=pd.read_csv("Wine_Quality.csv")

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        1
# 1      9.5        1
# 2     10.1        1
# ...

# %%
wine.shape
# Out:
# (4898, 12)

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
scaled_wine=pd.DataFrame(sc.fit_transform(wine.drop("quality",axis=1)), columns = wine.columns[:11])

# %%
scaled_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.172097         -0.081770     0.213280        2.821349  -0.035355
# 1         -0.657501          0.215896     0.048001       -0.944765   0.147747
# 2          1.475751          0.017452     0.543838        0.100282   0.193523
# 3          0.409125         -0.478657    -0.117278        0.415768   0.559727
# 4          0.409125         -0.478657    -0.117278        0.415768   0.559727
# 5          1.475751          0.017452     0.543838        0.100282   0.193523
# 6         -0.776015          0.414339    -1.439511        0.120000  -0.035355
# 7          0.172097         -0.081770     0.213280        2.821349  -0.035355
# 8         -0.657501          0.215896     0.048001       -0.944765   0.147747
# 9          1.475751         -0.577879     0.791757       -0.964483  -0.081131
# 10         1.475751         -0.081770     0.626478       -0.974342  -0.584661
# ...

# %%
x=scaled_wine
y=wine.quality

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,cohen_kappa_score

# %%
dt= DecisionTreeClassifier()

# %%
preds=dt.fit(xtrain,ytrain).predict(xtest)

# %%
accuracy_score(ytest,preds)
# Out:
# 0.763265306122449

# %%
cohen_kappa_score(ytest,preds)
# Out:
# 0.47520789178342737

# %%
#The above we have done using default supoose i want to churn the param then

# %%
dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
            max_features=None, max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
            splitter='best')
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
